# %%
import numpy as np

# %%
a = np.ones((5,10))
b = np.ones((5,10)) * 5


print(b-a)
# Out:
# [[4. 4. 4. 4. 4. 4. 4. 4. 4. 4.]
#  [4. 4. 4. 4. 4. 4. 4. 4. 4. 4.]
#  [4. 4. 4. 4. 4. 4. 4. 4. 4. 4.]
#  [4. 4. 4. 4. 4. 4. 4. 4. 4. 4.]
#  [4. 4. 4. 4. 4. 4. 4. 4. 4. 4.]]
