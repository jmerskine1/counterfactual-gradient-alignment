# %%
from counterfactual_alignment.utilities import plot_results
# Out:
# 25-Oct-08 23:17:16 fatf.utils.array.tools INFO     Using numpy's numpy.lib.recfunctions.structured_to_unstructured as fatf.utils.array.tools.structured_to_unstructured and fatf.utils.array.tools.structured_to_unstructured_row.

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/IMDB/model_outputs/"

results = [
    # "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.01__BATCHSIZE_32__trainsize_1707__active_False_smplsize_5_div0.8_LOSS_cross_entropy_mix_20",
    "integer_len16/MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.001__BATCHSIZE_32__trainsize_1707__active_False_smplsize_5_div0.8_LOSS_cross_entropy_mix_0",
    "integer_len32/MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.001__BATCHSIZE_32__trainsize_1707__active_False_smplsize_5_div0.8_LOSS_cross_entropy_mix_0"
    ]

plot_results(results=results,
    labels=['conv2 - 128','conv1 - 128'],
    path=dir, 
    loss=True,
    show_max=True)
# Out:
# (<Figure size 1600x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# Active larning initial sample 300, 60 every 2 epochs

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/IMDB/model_outputs/integer_len32"

results = [
    # "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.01__BATCHSIZE_32__trainsize_1707__active_False_smplsize_5_div0.8_LOSS_cross_entropy_mix_20",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_cross_entropy_mix_0",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_combined_loss_embedding_mix_0.5",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_combined_loss_embedding_mix_0.9",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_combined_loss_embedding_mix_1.0",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_cross_entropy_mix_1.0",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_combined_loss_embedding_mix_0.5",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_30_div0.8_LOSS_combined_loss_embedding_mix_0.5",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_30_div0.8_LOSS_cross_entropy_mix_0.5"
    
    ]

plot_results(results=results,
    labels=['conv2 - 128','conv1 - 128'],
    path=dir, 
    loss=True,
    show_max=True)
# Out:
# (<Figure size 1600x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# Without trainedstate reset

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/IMDB/model_outputs/integer_len32"

results = [
    # "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.01__BATCHSIZE_32__trainsize_1707__active_False_smplsize_5_div0.8_LOSS_cross_entropy_mix_20",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_cross_entropy_mix_0",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_combined_loss_embedding_mix_0.5",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_combined_loss_embedding_mix_0.9",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_combined_loss_embedding_mix_1.0",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_cross_entropy_mix_1.0",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_combined_loss_embedding_mix_0.5",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_30_div0.8_LOSS_combined_loss_embedding_mix_0.5",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_30_div0.8_LOSS_cross_entropy_mix_0.5",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_cross_entropy_mix_0.5"
    
    ]

plot_results(results=results,
    labels=['conv2 - 128','conv1 - 128'],
    path=dir, 
    loss=True,
    show_max=True)
# Out:
# (<Figure size 1600x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# control (last line) with double data - but reseting trainedstate with new data

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/IMDB/model_outputs/integer_len32"

results = [
    # "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.01__BATCHSIZE_32__trainsize_1707__active_False_smplsize_5_div0.8_LOSS_cross_entropy_mix_20",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_cross_entropy_mix_0",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_combined_loss_embedding_mix_0.5",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_combined_loss_embedding_mix_0.9",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_combined_loss_embedding_mix_1.0",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_cross_entropy_mix_1.0",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_combined_loss_embedding_mix_0.5",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_30_div0.8_LOSS_combined_loss_embedding_mix_0.5",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_30_div0.8_LOSS_cross_entropy_mix_0.5",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_cross_entropy_mix_0.5"
    
    ]

plot_results(results=results,
    labels=['conv2 - 128','conv1 - 128'],
    path=dir, 
    loss=True,
    show_max=True)
# Out:
# (<Figure size 1600x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# with trained state reset

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/IMDB/model_outputs/integer_len32"

results = [
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_cross_entropy_mix_0.5",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_30_div0.8_LOSS_combined_loss_embedding_mix_0.5"
    ]

plot_results(results=results,
    labels=['conv2 - 128','conv1 - 128'],
    path=dir, 
    loss=True,
    show_max=True)
# Out:
# (<Figure size 1600x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# without reset

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/IMDB/model_outputs/integer_len32"

results = [
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_3414__active_False_smplsize_60_div0.8_LOSS_cross_entropy_mix_0.5",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_60_div0.8_LOSS_cross_entropy_mix_0.5",
    "MODEL_ENSEMBLE_6_BagOfWordsClassifierSimple__emb50_OPTIM_adamw__LR_0.0001__BATCHSIZE_32__trainsize_1707__active_True_smplsize_30_div0.8_LOSS_combined_loss_embedding_mix_0.5"
    ]

plot_results(results=results,
    labels=['conv2 - 128','conv1 - 128'],
    path=dir, 
    loss=True,
    show_max=True)
# Out:
# (<Figure size 1600x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)
