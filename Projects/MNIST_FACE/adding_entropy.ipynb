# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_face__split__boundary_False"

plot_results([
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_True_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5001",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_True_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5001",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_True_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5002",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_True_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
    
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss w/out entropy','Direction Loss with entropy','Direction Loss with normailsed entropy'],
            title = "Entropy & Active Learning",
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>,
#  <Axes: title={'center': 'Entropy & Active Learning'}, xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_face__split__boundary_False"

plot_results([
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5002",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5002",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5001",
    
    
    
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss w/out entropy','Direction Loss with entropy','Direction Loss with normailsed entropy'],
            title = "Entropy & No Active Learning",
            xlims=(0,10)
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>,
#  <Axes: title={'center': 'Entropy & No Active Learning'}, xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/"

plot_results([
    "integer_len100__connected_True__path_face__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5002",
    "integer_len100__connected_True__path_face__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
    "integer_len100__connected_True__path_face__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5002",
    "integer_len100__connected_True__path_face__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5001",
    "integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5002",
    "integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5001",
    "integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_1.0",
    
    
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss w/out entropy','Direction Loss with entropy','Direction Loss with normailsed entropy','RAW Direction Loss with entropy','RAW Direction Loss with normailsed entropy',"less CE"],
            title = "Entropy & No Active Learning",
            # xlims=(0,15),
            show_max=True
            )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 6
#       3 # "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
#       4 path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/"
# ----> 6 plot_results([
#       7     "integer_len100__connected_True__path_face__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5002",
# ...

# %% [markdown]
# # smaller dataset, boundary only

# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/integer_len20__connected_True__path_raw__split__boundary_True"

plot_results([
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.501",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_1.0",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adabelief__LR_0.0001__BATCHSIZE_20__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.501",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9"
    
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss w/out entropy','Direction Loss with entropy','Direction Loss with normailsed entropy','RAW Direction Loss with entropy','RAW Direction Loss with normailsed entropy',"less CE"],
            title = "Entropy & No Active Learning",
            # xlims=(0,15),
            show_max=True
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>,
#  <Axes: title={'center': 'Entropy & No Active Learning'}, xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/"

plot_results([
    "integer_len20__connected_True__path_raw__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    "integer_len20__connected_True__path_raw__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.501",
    "integer_len20__connected_True__path_raw__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_1.0",
    "integer_len20__connected_True__path_raw__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
    "integer_len20__connected_True__path_raw__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adabelief__LR_0.0001__BATCHSIZE_20__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.501",
    "integer_len20__connected_True__path_raw__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    "integer_len20__connected_True__path_raw__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    "integer_len20__connected_True__path_pca__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss w/out entropy','Direction Loss with entropy','Direction Loss with normailsed entropy','RAW Direction Loss with entropy','RAW Direction Loss with normailsed entropy',"less CE"],
            title = "Entropy & No Active Learning",
            # xlims=(0,15),
            show_max=True
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>,
#  <Axes: title={'center': 'Entropy & No Active Learning'}, xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/"

plot_results([
    "integer_len20__connected_True__path_raw__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    
    "integer_len20__connected_True__path_face__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "integer_len20__connected_True__path_face__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.95",
    "integer_len20__connected_True__path_face__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.96",
    "integer_len20__connected_True__path_face__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.97",
    "integer_len20__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.97",
    "integer_len20__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.97",

    
              ],
            path=path,
            # labels=['CE Upper Bound','Direction Loss w/out entropy','Direction Loss with entropy','Direction Loss with normailsed entropy','RAW Direction Loss with entropy','RAW Direction Loss with normailsed entropy',"less CE"],
            title = "Entropy & No Active Learning",
            # xlims=(0,10),
            show_max=True
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>,
#  <Axes: title={'center': 'Entropy & No Active Learning'}, xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/"

plot_results([
    "integer_len20__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.97",
    "integer_len20__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.97",
    "integer_len20__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9701",
    "integer_len20__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9701",
    "integer_len20__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9701",

    
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss Softmax','Direction Loss with normalised entropy'],
            title = "Messing with loss and full paths",
            # xlims=(0,10),
            show_max=True
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>,
#  <Axes: title={'center': 'Messing with loss and full paths'}, xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/"

plot_results([
    "integer_len20__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.97",
    "integer_len20__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9701",
    "integer_len20__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9701",

    
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss Softmax','Direction Loss with normalised entropy'],
            title = "Messing with loss and full paths",
            # xlims=(0,10),
            show_max=True
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>,
#  <Axes: title={'center': 'Messing with loss and full paths'}, xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/integer_len20__connected_True__path_raw__split__boundary_False/"

plot_results([
    
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "MODEL_ENSEMBLE_1_ImprovedMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "MODEL_ENSEMBLE_1_RobustMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "MODEL_ENSEMBLE_1_OptimizedMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "MODEL_ENSEMBLE_1_SurpassingMNIST__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "MODEL_ENSEMBLE_1_SurpassingMNIST__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_OptimizedMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_ManifoldRobustConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_ManifoldRobustConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.901"

    
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss Softmax','Direction Loss with normalised entropy'],
            title = "Messing with loss and full paths",
            # xlims=(0,10),
            show_max=True
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>,
#  <Axes: title={'center': 'Messing with loss and full paths'}, xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/integer_len20__connected_True__path_raw__split__boundary_False/"

plot_results([
    "MODEL_ENSEMBLE_1_SurpassingMNIST__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "MODEL_ENSEMBLE_1_SurpassingMNIST__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_OptimizedMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_ManifoldRobustConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_ManifoldRobustConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.901",
    "MODEL_ENSEMBLE_1_ManifoldRobustConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.901",
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss Softmax','Direction Loss with normalised entropy'],
            title = "Messing with loss and full paths",
            # xlims=(0,10),
            show_max=True
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>,
#  <Axes: title={'center': 'Messing with loss and full paths'}, xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# # ^^^ Good results (+2%)
#
# checking with different dataset sizes

# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/integer_len40__connected_True__path_raw__split__boundary_False/"

plot_results([
    "MODEL_ENSEMBLE_1_ManifoldRobustConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_40__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.901",
    "MODEL_ENSEMBLE_1_ManifoldRobustConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_40__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.902",
    "MODEL_ENSEMBLE_1_ManifoldRobustConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_40__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.902",
    "MODEL_ENSEMBLE_1_ManifoldRobustConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_40__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.901",
    "MODEL_ENSEMBLE_1_ManifoldRobustConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_40__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.902",
    "MODEL_ENSEMBLE_1_ManifoldRobustConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_40__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.902",
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss Softmax','Direction Loss with normalised entropy'],
            title = "Messing with loss and full paths",
            # xlims=(0,10),
            show_max=True
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>,
#  <Axes: title={'center': 'Messing with loss and full paths'}, xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/integer_len40__connected_True__path_raw__split__boundary_False/"

plot_results([
    "MODEL_ENSEMBLE_6_ManifoldRobustConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_40__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.902",
    "MODEL_ENSEMBLE_6_ManifoldRobustConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_40__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.902",
    "MODEL_ENSEMBLE_6_ManifoldRobustConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_40__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.901",
    "MODEL_ENSEMBLE_1_ManifoldRobustConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_40__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.899",
    "MODEL_ENSEMBLE_1_ManifoldRobustConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_40__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.898",
    "MODEL_ENSEMBLE_1_ManifoldRobustConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_40__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.8985",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_40__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.8985",
    "MODEL_ENSEMBLE_1_OptimizedMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_40__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.8985",
    "MODEL_ENSEMBLE_1_OptimizedMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_40__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.8985"
    
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss with normalised entropy'],
            title = "Messing with loss and full paths",
            xlims=(0,10),
            show_max=True
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>,
#  <Axes: title={'center': 'Messing with loss and full paths'}, xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/integer_len200__connected_True__path_raw__split__boundary_False/"

plot_results([
    "MODEL_ENSEMBLE_1_OptimizedMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_200__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.8985",
    "MODEL_ENSEMBLE_1_OptimizedMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_200__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.8985",
    "MODEL_ENSEMBLE_1_OptimizedMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_200__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_OptimizedMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_200__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.901",
    "MODEL_ENSEMBLE_1_OptimizedMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_200__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.902",
    
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss with normalised entropy'],
            title = "Messing with loss and full paths",
            # xlims=(0,10),
            show_max=True
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>,
#  <Axes: title={'center': 'Messing with loss and full paths'}, xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# ## Adding entropy and active learning

# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/integer_len200__connected_True__path_raw__split__boundary_False/"

plot_results([
    "MODEL_ENSEMBLE_1_OptimizedMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_200__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.8985",
    "MODEL_ENSEMBLE_1_OptimizedMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_200__active_True_smplsize_10_div0.8_LOSS_multiclass_cross_entropy_mix_0.902",
    "MODEL_ENSEMBLE_1_OptimizedMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_200__active_True_smplsize_10_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.901",
    "MODEL_ENSEMBLE_1_OptimizedMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_200__active_True_smplsize_10_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.902",
    "MODEL_ENSEMBLE_1_OptimizedMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_200__active_True_smplsize_10_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.899",
    "MODEL_ENSEMBLE_1_OptimizedMNISTConv__emb64_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_200__active_True_smplsize_10_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.898"
    
    
              ],
            path=path,
            labels=['CE Upper Bound','CE AL','AL Direction Loss','AL Direction Loss with normalised entropy', "softplus(dd)/magnitude",'ignoring magnitude',],
            title = "Messing with loss and full paths",
            # xlims=(0,10),
            show_max=True
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>,
#  <Axes: title={'center': 'Messing with loss and full paths'}, xlabel='Epoch', ylabel='Accuracy'>)
