# %% [markdown]
# # Face Study 2
#
# ## Data Sensitivity
#
# We have confirmed that <b> Simple Model > Complex. </b> <br>
#
# To test whether direction loss or gradient supervision are better with more/less data, need to test sensirtivity to:
# - Dataset size without active learning
# - Dataset size with active learning
# - Number of counterfactuals
#     - Control including these counterfactuals and their labels just as training data
# - Active learning batch size
# - Active learning sample rate
# - Loss mix

# %%
from counterfactual_alignment.utilities import plot_results
# Out:
# 25-Nov-24 12:02:38 fatf.utils.array.tools INFO     Using numpy's numpy.lib.recfunctions.structured_to_unstructured as fatf.utils.array.tools.structured_to_unstructured and fatf.utils.array.tools.structured_to_unstructured_row.

# %% [markdown]
# Relying on the "original" set, so not filtering for just direct (start and end of paths) or local (where paths lie on the boundary)

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len20__connected_False__path_raw__length_original__cfn_3/"
paths = [
    "MODEL_ENSEMBLE_6_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_10_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "MODEL_ENSEMBLE_6_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_10_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_0.9",
    "MODEL_ENSEMBLE_6_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.9"
]

plot_results(
    paths,
    labels=['CE', 'GS', 'CL'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# Testing lower learning rate and reducing n_models = 1 for speed

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len20__connected_False__path_raw__length_original__cfn_3/"
paths = [
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.001__BATCHSIZE_8__trainsize_20__active_False_smplsize_10_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.001__BATCHSIZE_8__trainsize_20__active_False_smplsize_10_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.001__BATCHSIZE_8__trainsize_20__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.9"
]

plot_results(
    paths,
    labels=['CE', 'GS', 'CL'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# Increasing learning rate back up and confirming n_models = 1 isnt the cuplrit

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len20__connected_False__path_raw__length_original__cfn_3/"
paths = [
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_10_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_10_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.9"
]

plot_results(
    paths,
    labels=['CE', 'GS', 'CL'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len20__connected_False__path_raw__length_original__cfn_1/"
paths = [
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_10_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_10_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_10_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_1",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_20__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1",
]

plot_results(
    paths,
    labels=['CE', 'GS 0.9','GS 1','CL 0.9', 'CL 1'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len100__connected_False__path_raw__length_original__cfn_1/"
paths = [
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_10_div0.8_LOSS_multiclass_cross_entropy_mix_1",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_10_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_1",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb128_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1",
]

plot_results(
    paths,
    labels=['CE', 'GS 1','CL 1'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# Expanding width of network

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len100__connected_False__path_raw__length_original__cfn_1/"
paths = [
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_10_div0.8_LOSS_multiclass_cross_entropy_mix_1",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_10_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_1",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1",
]

plot_results(
    paths,
    labels=['CE', 'GS 1','CL 1'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# still shitty - increasing number of counterfactuals

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len100__connected_False__path_raw__length_original__cfn_2/"
paths = [
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_10_div0.8_LOSS_multiclass_cross_entropy_mix_1",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_10_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_1",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1",
]

plot_results(
    paths,
    labels=['CE', 'GS 1','CL 1'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len100__connected_False__path_raw__length_original__cfn_3/"
paths = [
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_10_div0.8_LOSS_multiclass_cross_entropy_mix_1",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_10_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_1",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1",
]

plot_results(
    paths,
    labels=['CE', 'GS 1','CL 1'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len500__connected_False__path_raw__length_original__cfn_1/"
paths = [
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_500__active_False_smplsize_10_div0.8_LOSS_multiclass_cross_entropy_mix_1",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_500__active_False_smplsize_10_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_1",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_500__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1",
]

plot_results(
    paths,
    labels=['CE', 'GS 1','CL 1'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len500__connected_False__path_raw__length_original__cfn_1/"
paths = [
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_500__active_False_smplsize_10_div0.8_LOSS_multiclass_cross_entropy_mix_0.99",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_500__active_False_smplsize_10_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_0.99",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adamw__LR_0.0001__BATCHSIZE_8__trainsize_500__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.99",
]

plot_results(
    paths,
    labels=['CE', 'GS 1','CL 1'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# ### ADABELIEF Optimiser

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len500__connected_False__path_raw__length_original__cfn_1/"
paths = [
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_500__active_False_smplsize_10_div0.8_LOSS_multiclass_cross_entropy_mix_0.99",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_500__active_False_smplsize_10_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_0.99",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_500__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.99",
]

plot_results(
    paths,
    labels=['CE', 'GS 1','CL 1'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# dividing data by 10

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len50__connected_False__path_raw__length_original__cfn_1/"
paths = [
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_10_div0.8_LOSS_multiclass_cross_entropy_mix_0.99",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_10_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_0.99",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.99",
]

plot_results(
    paths,
    labels=['CE', 'GS 1','CL 1'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# changing loss mix

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len50__connected_False__path_raw__length_original__cfn_1/"
paths = [
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_10_div0.8_LOSS_multiclass_cross_entropy_mix_0.2",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_10_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_0.2",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.2",
]

plot_results(
    paths,
    labels=['CE', 'GS 1','CL 1'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# messing with direction loss function

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len50__connected_False__path_raw__length_original__cfn_1/"
paths = [
    
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1_relu_magnitude",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1_softplus_magnitude",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1_softplus_knorm",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1distance",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1hessian",
]

plot_results(
    paths,
    labels=['CE', 'GS 1','CL 1'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# multiclass_direction_hinge did ok..

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/"
paths = [
    
    
    "integer_len50__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.9hessian",
    "integer_len50__connected_False__path_face__length_original__cfn_1/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.9hessian",
    "integer_len50__connected_False__path_pca__length_original__cfn_1/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.9hessian",
]

plot_results(
    paths,
    labels=['CE', 'GS 1','CL 1'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# Increasing counterfactuals

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/"
paths = [
    "integer_len500__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_500__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1.0",
    "integer_len500__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_500__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1.0hessian",
    "integer_len500__connected_False__path_raw__length_original__cfn_2/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_500__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1.0",
    "integer_len500__connected_False__path_raw__length_original__cfn_2/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_500__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1.0hessian",
    "integer_len500__connected_False__path_raw__length_original__cfn_3/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_500__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1.0",
    "integer_len500__connected_False__path_raw__length_original__cfn_3/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_500__active_False_smplsize_10_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1.0hessian",
]

plot_results(
    paths,
    labels=['CF1','CF1 Hessian', 'CF2','CF2 Hessian', 'CF3','CF3 Hessian'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/"
paths = [
    
    "integer_len50__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1.0",
    "integer_len50__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1.0",
    "integer_len50__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_1.0",
    "integer_len50__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.5",
    "integer_len50__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
]

plot_results(
    paths,
    labels=['CF1','CF1 Hessian', 'CF2','CF2 Hessian', 'CF3','CF3 Hessian'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/"
paths = [
    "integer_len50__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    "integer_len50__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.5",
    "integer_len50__connected_False__path_raw__length_original__cfn_2/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.5",
    "integer_len50__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_0.5",
    "integer_len50__connected_False__path_raw__length_original__cfn_2/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_0.5",
    
]

plot_results(
    paths,
    labels=['CE','dir',],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/"
paths = [
    "integer_len50__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    "integer_len50__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.5",
    "integer_len50__connected_False__path_raw__length_original__cfn_2/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.5",
    "integer_len50__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_0.5",
    "integer_len50__connected_False__path_raw__length_original__cfn_2/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_0.5",
    "integer_len50__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini2__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.5",
    "integer_len50__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini2__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_True_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
]

plot_results(
    paths,
    labels=['CE','dir',],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# Magnitude vs 10

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len50__connected_False__path_raw__length_original__cfn_1/"
paths = [
    "MODEL_ENSEMBLE_1_MNISTConvClassifierGemini2__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    "MODEL_ENSEMBLE_1_MNISTConvClassifierGemini2__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.5_10_not_mag",
    "MODEL_ENSEMBLE_1_MNISTConvClassifierGemini2__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_combined_loss_embedding_mix_0.5"
]

plot_results(
    paths,
    labels=['CE','dir',],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/"
paths = [
    "integer_len50__connected_False__path_face__length_original__cfn_1/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini2__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    "integer_len50__connected_False__path_face__length_original__cfn_1/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini2__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1",
    "integer_len50__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini2__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_combined_loss_embedding_mix_1",
    "integer_len50__connected_False__path_face__length_original__cfn_1/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini2__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_1",
    "integer_len50__connected_False__path_raw__length_original__cfn_1/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini2__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_gradient_supervision_embedding_mix_1"
]

plot_results(
    paths,
    labels=['CE','dir','GS'],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# test with less points for CE
