# %%
from counterfactual_alignment.utilities import plot_results
# Out:
# 25-Dec-09 10:05:13 fatf.utils.array.tools INFO     Using numpy's numpy.lib.recfunctions.structured_to_unstructured as fatf.utils.array.tools.structured_to_unstructured and fatf.utils.array.tools.structured_to_unstructured_row.

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len50__connected_True__path_face__split__boundary_True/"


plot_results([
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_split_gs_embedding_mix_0.5",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5_softplus"
    
],
labels=['crossentropy','gradient supervision','direction','softplus'],
path=path, 
loss=True,
show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len50__connected_True__path_face__split__boundary_False/"


plot_results([
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_split_gs_embedding_mix_0.5",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5_softplus"
    
],
labels=['crossentropy','gradient supervision','direction','softplus'],
path=path, 
loss=True,
show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len50__connected_True__path_face__split__boundary_False/"


plot_results([
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_split_gs_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9_softplus"
    
],
labels=['crossentropy','gradient supervision','direction','softplus'],
path=path, 
loss=True,
show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len10__connected_True__path_face__split__boundary_False/"


plot_results([
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_10__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_10__active_False_smplsize_5_div0.8_LOSS_multiclass_split_gs_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_10__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_10__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9softplus",
    
],
labels=['crossentropy','gradient supervision','direction','softplus'],
path=path, 
loss=True,
show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_face__split__boundary_False/"


plot_results([
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_gs_embedding_mix_0.9",
    # "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_10__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9_softplus",
    
],
labels=['crossentropy','gradient supervision','direction','softplus'],
path=path, 
loss=True,
show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_face__split__boundary_True/"


plot_results([
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_gs_embedding_mix_0.9",
    # "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_10__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9_softplus",
    
],
labels=['crossentropy','gradient supervision','direction','softplus'],
path=path, 
loss=True,
show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/"


plot_results([
    "integer_len100__connected_True__path_face__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "integer_len100__connected_True__path_face__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_gs_embedding_mix_0.9",
    # "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_10__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    "integer_len100__connected_True__path_face__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9_softplus",
    
    "integer_len100__connected_True__path_face__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "integer_len100__connected_True__path_face__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_gs_embedding_mix_0.9",
    # "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_10__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9",
    "integer_len100__connected_True__path_face__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.9_softplus",
    
],
labels=['crossentropy','gradient supervision','direction','crossentropy','gradient supervision','direction'],
path=path, 
loss=True,
show_max=True
)
# Out:
# (<Figure size 1200x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)
