# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/Circles/"

plot_results([
    "MODEL_ENSEMBLE_1_SimpleClassifier_v2__emb64_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.1",
    "MODEL_ENSEMBLE_1_SimpleClassifier_v2__emb64_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.1",
    "MODEL_ENSEMBLE_1_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.91"
    # 'MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_XSQUARED_filtered__LOSS_multiclass_split_loss_alpha_1.0__SIZE2FULL',
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss 0.5']
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/Circles/"

plot_results([
    "MODEL_ENSEMBLE_1_SimpleClassifier_v2__emb64_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.1",
    "MODEL_ENSEMBLE_1_SimpleClassifier_v2__emb64_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.1",
    "MODEL_ENSEMBLE_1_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    "MODEL_ENSEMBLE_1_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.91"
    # 'MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_XSQUARED_filtered__LOSS_multiclass_split_loss_alpha_1.0__SIZE2FULL',
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss 0.5']
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)
