# %%
from counterfactual_alignment.utilities import plot_results

path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/XSQUARED/"

plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__LOSS_multiclass_cross_entropy_alpha_1.0__SIZE2",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__LOSS_multiclass_split_loss_alpha_1.0__SIZE2"
    # 'MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_XSQUARED_filtered__LOSS_multiclass_split_loss_alpha_1.0__SIZE2FULL',
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss']
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/outputs/XSQUARED/"

plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_XSQUARED_filtered__LOSS_multiclass_cross_entropy_alpha_1.0__SIZE8",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_XSQUARED_filtered__LOSS_multiclass_split_loss_alpha_1.0__SIZE8",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_XSQUARED_filtered__LOSS_multiclass_split_loss_alpha_0.5__SIZE8"

    # 'MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_XSQUARED_filtered__LOSS_multiclass_split_loss_alpha_1.0__SIZE2FULL',
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss']
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/outputs/Circles/"

plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_Circles_filtered__LOSS_multiclass_cross_entropy_alpha_0.5__SIZE8",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_Circles_filtered__LOSS_multiclass_split_loss_alpha_0.5__SIZE8"

    # 'MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_XSQUARED_filtered__LOSS_multiclass_split_loss_alpha_1.0__SIZE2FULL',
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss']
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/outputs/TwoMoons/"

plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_TwoMoons_filtered__LOSS_multiclass_cross_entropy_alpha_0.5__SIZE8",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_TwoMoons_filtered__LOSS_multiclass_split_loss_alpha_0.5__SIZE8"

    # 'MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_XSQUARED_filtered__LOSS_multiclass_split_loss_alpha_1.0__SIZE2FULL',
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss']
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/outputs/TwoMoons/"

plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_TwoMoons_filtered__LOSS_multiclass_cross_entropy_alpha_0.5__SIZE8",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_TwoMoons_filtered__LOSS_multiclass_split_loss_alpha_0.5__SIZE8",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_TwoMoons_filtered__LOSS_multiclass_split_loss_alpha_1.0__SIZE8"

    # 'MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_XSQUARED_filtered__LOSS_multiclass_split_loss_alpha_1.0__SIZE2FULL',
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss 0.5','Direction Loss 1.0']
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# ## Circles

# %%
from counterfactual_alignment.utilities import plot_results

path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/outputs/Circles/"

plot_results([
    
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_Circles_filtered__LOSS_multiclass_cross_entropy_alpha_0.5__SIZE8",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_Circles_filtered__LOSS_multiclass_split_loss_alpha_0.5__SIZE8",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_Circles_filtered__LOSS_multiclass_split_loss_alpha_1.0__SIZE8"

    # 'MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_XSQUARED_filtered__LOSS_multiclass_split_loss_alpha_1.0__SIZE2FULL',
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss 0.5','Direction Loss 1.0']
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/"

plot_results([
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    "MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
    
    # 'MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_XSQUARED_filtered__LOSS_multiclass_split_loss_alpha_1.0__SIZE2FULL',
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss 0.5']
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# ## comparing raw, pca and face for cross entropy and direction
#
# ### n = 50

# %%
# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/"

plot_results([
    "integer_len50__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    "integer_len50__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
    "integer_len50__connected_True__path_pca__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    "integer_len50__connected_True__path_pca__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
    "integer_len50__connected_True__path_face__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    "integer_len50__connected_True__path_face__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
              ],
            path=path,
            labels=['Raw$_{CE}$',"Raw$_D$",'PCA$_{CE}$','PCA$_{D}$','FACE$_{CE}$','FACE$_{D}$']
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# ### n=100

# %%
# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/"

plot_results([
    "integer_len100__connected_True__path_pca__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    "integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
    "integer_len100__connected_True__path_pca__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
    "integer_len100__connected_True__path_face__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
              ],
            path=path,
            labels=['CE$_{PCA}$',"D$_{Raw}$",'D$_{PCA}$','PCA$_{D}$','FACE$_{CE}$','FACE$_{D}$']
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
from counterfactual_alignment.utilities import plot_results

# "Projects/MNIST_FACE/model_outputs/integer_len100__connected_True__path_raw__split__boundary_False/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_100__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5.pkl"
path = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/MNIST_FACE/model_outputs/"

plot_results([
    "integer_len50__connected_True__path_raw__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    "integer_len50__connected_True__path_raw__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
    "integer_len50__connected_True__path_face__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
    "integer_len50__connected_True__path_pca__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_embedding_mix_0.5",
    "integer_len50__connected_True__path_pca__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    "integer_len50__connected_True__path_raw__split__boundary_True/MODEL_ENSEMBLE_1_SimpleMNISTConv__emb256_OPTIM_adabelief__LR_0.0001__BATCHSIZE_8__trainsize_50__active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.5",
    
    
    # 'MODEL_ENSEMBLE_6_SimpleClassifier_v2__OPTIM_adam_opt__LR_0.01__BATCHSIZE_32__DATA_XSQUARED_filtered__LOSS_multiclass_split_loss_alpha_1.0__SIZE2FULL',
              ],
            path=path,
            labels=['CE Upper Bound','Direction Loss 0.5']
            )
# Out:
# (<Figure size 1200x800 with 1 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)
