# %%
from counterfactual_alignment.utilities import plot_results

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/GaussianQuartiles/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_200_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    # "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_sign",
    
    # "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_relu",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus_nv_2",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus_nv_2",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus_nv_3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus_nv_3",

    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_relu_nv_3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_relu_nv_3",

    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_sign_nv_3",
    # "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    # "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_relu",
    # "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.9_relu",
    # "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus",
    # "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_sign",
],

labels=['Cross entropy Upper bound','CE subsample','GS nostem','gs stopwords','GS','softplus','sign','softplus 1.0',],
path=path, 
loss=True,
show_max = True
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/GaussianQuartiles/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_200_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    # "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_sign",
    
    # "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_relu",
    
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus_nv_1",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus_nv_2",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus_nv_2",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus_nv_5",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus_nv_5",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_gs_2d_wrapper_mix_0.3",
    
    # "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.9",
    # "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_relu",
    # "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.9_relu",
    # "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus",
    # "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix
    # _0.3_sign",
],

labels=['Cross entropy Upper bound','CE subsample','GS nostem','gs stopwords','GS','softplus','sign','softplus 1.0',],
path=path, 
loss=True,
show_max = True
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# ## 16 points 5 cfs

# %%
"MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_16_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3"


path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/GaussianQuartiles/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_16_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_16_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3"
],

labels=['Cross entropy Upper bound','CE subsample','GS nostem','gs stopwords','GS','softplus','sign','softplus 1.0',],
path=path, 
loss=True,
show_max = True
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/GaussianQuartilesHard/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_15_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_15_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_15_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
    
    
],

labels=['Cross entropy Upper bound','CE subsample','GS nostem','gs stopwords','GS','softplus','sign','softplus 1.0',],
path=path, 
loss=True,
show_max = True
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/GaussianQuartilesHard/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_50_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_50_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
    
    
    
],

labels=['Cross entropy Upper bound','CE subsample','GS nostem','gs stopwords','GS','softplus','sign','softplus 1.0',],
path=path, 
loss=True,
show_max = True
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/GaussianQuartilesHardMulticlass/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_50_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_25_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_50_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_25_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
    
    
    
    
],

labels=['Cross entropy Upper bound','CE subsample','GS nostem','gs stopwords','GS','softplus','sign','softplus 1.0',],
path=path, 
loss=True,
show_max = True
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/GaussianQuartiles/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_25_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_25_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_gs_2d_wrapper_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_25_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
    
    
    
    
    
    
],

labels=['Cross entropy Upper bound','CE subsample','GS nostem','gs stopwords','GS','softplus','sign','softplus 1.0',],
path=path, 
loss=True,
show_max = True
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/Blobs/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_25_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_gs_2d_wrapper_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_25_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_25_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_25_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.0001__BATCHSIZE_32__trainsize_25_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.0001__BATCHSIZE_32__trainsize_25_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
    
    
],

labels=['Cross entropy Upper bound','CE subsample','GS nostem','gs stopwords','GS','softplus','sign','softplus 1.0',],
path=path, 
loss=True,
show_max = True
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/Blobs/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb64_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb64_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_10_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb64_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_6_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb64_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb64_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_6_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
],

labels=['Cross entropy Upper bound','CE subsample','GS nostem','gs stopwords','GS','softplus','sign','softplus 1.0',],
path=path, 
loss=True,
show_max = True 
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/Blobs/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb64_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_6_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb64_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_6_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb64_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_6_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_6_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_6_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_6_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_2vec",
],

labels=['Cross entropy Upper bound','CE subsample','GS nostem','gs stopwords','GS','softplus','sign','softplus 1.0',],
path=path, 
loss=True,
show_max = True
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# ## New blob

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/Blobs/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3_newBlob",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_newBlob",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3_newBlob",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_newBlob",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.9_newBlob",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.9_newBlob_sign",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.9_newBlob_relu",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb64_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.9_newBlob_relu",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.9_newBlob_relu",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.9_5v_softmax",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_5v_softmax",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v3__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_8_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_5v_softmax",

    
    
    
],

labels=['Cross entropy Upper bound','CE subsample','GS nostem','gs stopwords','GS','softplus','sign','softplus 1.0',],
path=path, 
loss=True,
show_max = True
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/Blobs/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_12_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_12_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_12_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_sign",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_12_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_relu",
],

labels=['CE','Softmax','Sign'],
path=path, 
loss=True,
show_max = True
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/Blobs/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_20_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_relu",
    
],

labels=['Cross entropy Upper bound','CE subsample','GS nostem','gs stopwords','GS','softplus','sign','softplus 1.0',],
path=path, 
loss=True,
show_max = True
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/Blobs/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_gs_2d_wrapper_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_relu",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softmax",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softmax",
],

labels=['Cross entropy Upper bound','CE subsample','GS nostem','gs stopwords','GS','softplus','sign','softplus 1.0',],
path=path, 
loss=True,
show_max = True
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/Blobs/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_sign",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_sign",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_100_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_relu",
    
],

labels=['Cross entropy Upper bound','CE subsample','GS nostem','gs stopwords','GS','softplus','sign','softplus 1.0',],
path=path, 
loss=True,
show_max = True
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/Blobs/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_60_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_60_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_60_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.9",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_60_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.9_softplus",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_60_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus_random",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_60_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus_random",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_60_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.9_softplus_random",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_60_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.9_softplus_random_0.8",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_60_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.5_sign_random_0.8",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_60_counterfactual_breadcrumbs_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.5_sign_random_0.2",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_60_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_relu_random_0.2",
],

labels=['Cross entropy Upper bound','CE subsample','GS nostem','gs stopwords','GS','softplus','sign','softplus 1.0',],
path=path, 
loss=True,
show_max = True
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %%
path ="/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment-cli/Projects/FACE_2D/model_outputs/Blobs/"


plot_results([
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_60_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_cross_entropy_mix_0.3",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_60_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_gs_2d_wrapper_mix_0.3_r=1.0",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_60_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus_r=0.5",
    "MODEL_ENSEMBLE_6_SimpleClassifier_v2__emb512_OPTIM_adabelief__LR_0.001__BATCHSIZE_32__trainsize_60_counterfactual_active_False_smplsize_5_div0.8_LOSS_multiclass_split_loss_mix_0.3_softplus_r=1.0",
    
],

labels=['CE','GS','D r=0.5','D R=1.0'],
path=path, 
loss=True,
show_max = True
)
# Out:
# (<Figure size 800x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)
