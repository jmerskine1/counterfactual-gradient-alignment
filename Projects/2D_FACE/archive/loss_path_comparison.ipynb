# %%
from counterfactual_alignment.utilities import plot_results

# %% [markdown]
# ## PATHS VS LOSS FUNCTIONS

# %% [markdown]
# integer_len50__connected_False__path_pca__length_local/

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/"
paths = [
    
    "integer_len50__connected_False__path_pca__length_local/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_pca__length_local_filtered__LOSS_multiclass_cross_entropy_mix_0.5",
    "integer_len50__connected_False__path_pca__length_local/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_pca__length_local_filtered__LOSS_multiclass_gradient_supervision_embedding_mix_0.5",
    "integer_len50__connected_False__path_pca__length_local/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_pca__length_local_filtered__LOSS_multiclass_combined_loss_embedding_mix_0.5"
    
]

plot_results(
    paths,
    labels=['Cross Entropy',"Gradient Supervision","Directional"],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1600x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# integer_len50__connected_False__path_pca__length_direct

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/"
paths = [
    
    "integer_len50__connected_False__path_pca__length_direct/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_pca__length_direct_filtered__LOSS_multiclass_cross_entropy_mix_0.5",
    "integer_len50__connected_False__path_pca__length_direct/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_pca__length_direct_filtered__LOSS_multiclass_gradient_supervision_embedding_mix_0.5",
    "integer_len50__connected_False__path_pca__length_direct/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_pca__length_direct_filtered__LOSS_multiclass_combined_loss_embedding_mix_0.5"

]

plot_results(
    paths,
    labels=['Cross Entropy',"Gradient Supervision","Directional"],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1600x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# integer_len50__connected_False__path_raw__length_local

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/"
paths = [
    
    
    "integer_len50__connected_False__path_raw__length_local/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_raw__length_local_filtered__LOSS_multiclass_cross_entropy_mix_0.5",
    "integer_len50__connected_False__path_raw__length_local/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_raw__length_local_filtered__LOSS_multiclass_gradient_supervision_embedding_mix_0.5",
    "integer_len50__connected_False__path_raw__length_local/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_raw__length_local_filtered__LOSS_multiclass_combined_loss_embedding_mix_0.5"
    
]

plot_results(
    paths,
    labels=['Cross Entropy',"Gradient Supervision","Directional"],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1600x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# integer_len50__connected_False__path_raw__length_direct

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/"
paths = [
    
    "integer_len50__connected_False__path_raw__length_direct/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_raw__length_direct_filtered__LOSS_multiclass_cross_entropy_mix_0.5",
    "integer_len50__connected_False__path_raw__length_direct/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_raw__length_direct_filtered__LOSS_multiclass_gradient_supervision_embedding_mix_0.5",
    "integer_len50__connected_False__path_raw__length_direct/MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_raw__length_direct_filtered__LOSS_multiclass_combined_loss_embedding_mix_0.5"
]

plot_results(
    paths,
    labels=['Cross Entropy',"Gradient Supervision","Directional"],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1600x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# integer_len50__connected_False__path_face__length_local

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len50__connected_False__path_face__length_local/"
paths = [
    
    "MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_face__length_local_filtered__LOSS_multiclass_cross_entropy_mix_0.5",
    "MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_face__length_local_filtered__LOSS_multiclass_gradient_supervision_embedding_mix_0.5",
    "MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_face__length_local_filtered__LOSS_multiclass_combined_loss_embedding_mix_0.5"
]

plot_results(
    paths,
    labels=['Cross Entropy',"Gradient Supervision","Directional"],
    path=dir, 
    loss=True,
    show_max=True
)
# Out:
# (<Figure size 1600x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# integer_len50__connected_False__path_face__length_direct

# %%
dir = "/Users/jonathanerskine/University of Bristol/gradient_supervision/counterfactual-gradient-alignment/Projects/MNIST_FACE/model_outputs/integer_len50__connected_False__path_face__length_direct/"
paths = [
    "MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_face__length_direct_filtered__LOSS_multiclass_cross_entropy_mix_0.5",
    "MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_face__length_direct_filtered__LOSS_multiclass_gradient_supervision_embedding_mix_0.5",
    "MODEL_ENSEMBLE_1_MNISTConvClassifierGemini_embeddingsize_512_OPTIM_adamw_wd_0.01__LR_0.0001__BATCHSIZE_8__DATA_integer_len50__connected_False__path_face__length_direct_filtered__LOSS_multiclass_combined_loss_embedding_mix_0.5"
]

plot_results(
    paths,
    labels=['Cross Entropy',"Gradient Supervision","Directional"],
    path=dir, 
    loss=True,
    show_max=True,
)
# Out:
# (<Figure size 1600x800 with 2 Axes>, <Axes: xlabel='Epoch', ylabel='Accuracy'>)

# %% [markdown]
# ## train with complete paths
